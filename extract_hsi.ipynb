# %%
import scipy.io

# Load the .mat file
mat_file_path = "data/pre/ARAD_HS_0301.mat"
mat_data = scipy.io.loadmat(mat_file_path)

# Print all available keys in the .mat file
print(mat_data.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'cube', 'bands', 'norm_factor'])

# %%
import os
import numpy as np
import tifffile as tiff
from scipy.io import loadmat

# Folder containing the .mat files
input_folder = "data/pre"

# Folder to save the extracted TIFF files
output_folder = "data/post"
os.makedirs(output_folder, exist_ok=True)  # Create the output folder if it doesn't exist

# Get all .mat files in the input folder
mat_files = [f for f in os.listdir(input_folder) if f.endswith('.mat')]

# Loop through each .mat file
for mat_file in mat_files:
    mat_file_path = os.path.join(input_folder, mat_file)  # Full path of the .mat file
    
    # Load the .mat file
    mat_data = loadmat(mat_file_path)

    # Extract the 'cube' data
    if 'cube' in mat_data:
        cube_data = mat_data['cube']
        
        # Create a folder for the current .mat file's bands
        mat_file_name = os.path.splitext(mat_file)[0]
        mat_output_folder = os.path.join(output_folder, mat_file_name)
        os.makedirs(mat_output_folder, exist_ok=True)

        # Loop through each band and save as a TIFF file
        for i in range(cube_data.shape[2]):
            band_data = cube_data[:, :, i]
            tiff_file_path = os.path.join(mat_output_folder, f'{mat_file_name}_band_{i + 1}.tiff')
            tiff.imwrite(tiff_file_path, band_data.astype(np.float32))  # Save the TIFF file
        print(f"Extracted {cube_data.shape[2]} bands from {mat_file} and saved as TIFF in {mat_output_folder}.")
    else:
        print(f"'cube' key not found in {mat_file}.")
# Out:
# Extracted 31 bands from ARAD_HS_0301.mat and saved as TIFF in data/post\ARAD_HS_0301.
# Extracted 31 bands from ARAD_HS_0302.mat and saved as TIFF in data/post\ARAD_HS_0302.
# Extracted 31 bands from ARAD_HS_0303.mat and saved as TIFF in data/post\ARAD_HS_0303.
# Extracted 31 bands from ARAD_HS_0304.mat and saved as TIFF in data/post\ARAD_HS_0304.
# Extracted 31 bands from ARAD_HS_0305.mat and saved as TIFF in data/post\ARAD_HS_0305.
# Extracted 31 bands from ARAD_HS_0306.mat and saved as TIFF in data/post\ARAD_HS_0306.
# Extracted 31 bands from ARAD_HS_0307.mat and saved as TIFF in data/post\ARAD_HS_0307.
# Extracted 31 bands from ARAD_HS_0308.mat and saved as TIFF in data/post\ARAD_HS_0308.
# Extracted 31 bands from ARAD_HS_0309.mat and saved as TIFF in data/post\ARAD_HS_0309.
# Extracted 31 bands from ARAD_HS_0310.mat and saved as TIFF in data/post\ARAD_HS_0310.
# Extracted 31 bands from ARAD_HS_0311.mat and saved as TIFF in data/post\ARAD_HS_0311.
# Extracted 31 bands from ARAD_HS_0312.mat and saved as TIFF in data/post\ARAD_HS_0312.
# Extracted 31 bands from ARAD_HS_0313.mat and saved as TIFF in data/post\ARAD_HS_0313.
# Extracted 31 bands from ARAD_HS_0314.mat and saved as TIFF in data/post\ARAD_HS_0314.
# Extracted 31 bands from ARAD_HS_0315.mat and saved as TIFF in data/post\ARAD_HS_0315.
# Extracted 31 bands from ARAD_HS_0316.mat and saved as TIFF in data/post\ARAD_HS_0316.
# Extracted 31 bands from ARAD_HS_0317.mat and saved as TIFF in data/post\ARAD_HS_0317.
# Extracted 31 bands from ARAD_HS_0318.mat and saved as TIFF in data/post\ARAD_HS_0318.
# Extracted 31 bands from ARAD_HS_0319.mat and saved as TIFF in data/post\ARAD_HS_0319.
# Extracted 31 bands from ARAD_HS_0320.mat and saved as TIFF in data/post\ARAD_HS_0320.
# Extracted 31 bands from ARAD_HS_0321.mat and saved as TIFF in data/post\ARAD_HS_0321.
# Extracted 31 bands from ARAD_HS_0322.mat and saved as TIFF in data/post\ARAD_HS_0322.
# Extracted 31 bands from ARAD_HS_0323.mat and saved as TIFF in data/post\ARAD_HS_0323.
# Extracted 31 bands from ARAD_HS_0324.mat and saved as TIFF in data/post\ARAD_HS_0324.
# Extracted 31 bands from ARAD_HS_0325.mat and saved as TIFF in data/post\ARAD_HS_0325.
# Extracted 31 bands from ARAD_HS_0326.mat and saved as TIFF in data/post\ARAD_HS_0326.
# Extracted 31 bands from ARAD_HS_0327.mat and saved as TIFF in data/post\ARAD_HS_0327.
# Extracted 31 bands from ARAD_HS_0328.mat and saved as TIFF in data/post\ARAD_HS_0328.
# Extracted 31 bands from ARAD_HS_0329.mat and saved as TIFF in data/post\ARAD_HS_0329.
# Extracted 31 bands from ARAD_HS_0330.mat and saved as TIFF in data/post\ARAD_HS_0330.
# Extracted 31 bands from ARAD_HS_0331.mat and saved as TIFF in data/post\ARAD_HS_0331.
# Extracted 31 bands from ARAD_HS_0332.mat and saved as TIFF in data/post\ARAD_HS_0332.
# Extracted 31 bands from ARAD_HS_0333.mat and saved as TIFF in data/post\ARAD_HS_0333.
# Extracted 31 bands from ARAD_HS_0334.mat and saved as TIFF in data/post\ARAD_HS_0334.
# Extracted 31 bands from ARAD_HS_0335.mat and saved as TIFF in data/post\ARAD_HS_0335.
# Extracted 31 bands from ARAD_HS_0336.mat and saved as TIFF in data/post\ARAD_HS_0336.
# Extracted 31 bands from ARAD_HS_0337.mat and saved as TIFF in data/post\ARAD_HS_0337.
# Extracted 31 bands from ARAD_HS_0338.mat and saved as TIFF in data/post\ARAD_HS_0338.
# Extracted 31 bands from ARAD_HS_0339.mat and saved as TIFF in data/post\ARAD_HS_0339.
# Extracted 31 bands from ARAD_HS_0340.mat and saved as TIFF in data/post\ARAD_HS_0340.
# Extracted 31 bands from ARAD_HS_0341.mat and saved as TIFF in data/post\ARAD_HS_0341.
# Extracted 31 bands from ARAD_HS_0342.mat and saved as TIFF in data/post\ARAD_HS_0342.
# Extracted 31 bands from ARAD_HS_0343.mat and saved as TIFF in data/post\ARAD_HS_0343.
# Extracted 31 bands from ARAD_HS_0344.mat and saved as TIFF in data/post\ARAD_HS_0344.
# Extracted 31 bands from ARAD_HS_0345.mat and saved as TIFF in data/post\ARAD_HS_0345.
# Extracted 31 bands from ARAD_HS_0346.mat and saved as TIFF in data/post\ARAD_HS_0346.
# Extracted 31 bands from ARAD_HS_0347.mat and saved as TIFF in data/post\ARAD_HS_0347.
# Extracted 31 bands from ARAD_HS_0348.mat and saved as TIFF in data/post\ARAD_HS_0348.
# Extracted 31 bands from ARAD_HS_0349.mat and saved as TIFF in data/post\ARAD_HS_0349.
# Extracted 31 bands from ARAD_HS_0350.mat and saved as TIFF in data/post\ARAD_HS_0350.
# Extracted 31 bands from ARAD_HS_0351.mat and saved as TIFF in data/post\ARAD_HS_0351.
# Extracted 31 bands from ARAD_HS_0352.mat and saved as TIFF in data/post\ARAD_HS_0352.
# Extracted 31 bands from ARAD_HS_0353.mat and saved as TIFF in data/post\ARAD_HS_0353.
# Extracted 31 bands from ARAD_HS_0354.mat and saved as TIFF in data/post\ARAD_HS_0354.
# Extracted 31 bands from ARAD_HS_0355.mat and saved as TIFF in data/post\ARAD_HS_0355.
# Extracted 31 bands from ARAD_HS_0356.mat and saved as TIFF in data/post\ARAD_HS_0356.
# Extracted 31 bands from ARAD_HS_0357.mat and saved as TIFF in data/post\ARAD_HS_0357.
# Extracted 31 bands from ARAD_HS_0358.mat and saved as TIFF in data/post\ARAD_HS_0358.
# Extracted 31 bands from ARAD_HS_0359.mat and saved as TIFF in data/post\ARAD_HS_0359.
# Extracted 31 bands from ARAD_HS_0360.mat and saved as TIFF in data/post\ARAD_HS_0360.
# Extracted 31 bands from ARAD_HS_0361.mat and saved as TIFF in data/post\ARAD_HS_0361.
# Extracted 31 bands from ARAD_HS_0362.mat and saved as TIFF in data/post\ARAD_HS_0362.
# Extracted 31 bands from ARAD_HS_0363.mat and saved as TIFF in data/post\ARAD_HS_0363.
# Extracted 31 bands from ARAD_HS_0364.mat and saved as TIFF in data/post\ARAD_HS_0364.
# Extracted 31 bands from ARAD_HS_0365.mat and saved as TIFF in data/post\ARAD_HS_0365.
# Extracted 31 bands from ARAD_HS_0366.mat and saved as TIFF in data/post\ARAD_HS_0366.
# Extracted 31 bands from ARAD_HS_0367.mat and saved as TIFF in data/post\ARAD_HS_0367.
# Extracted 31 bands from ARAD_HS_0368.mat and saved as TIFF in data/post\ARAD_HS_0368.
# Extracted 31 bands from ARAD_HS_0369.mat and saved as TIFF in data/post\ARAD_HS_0369.
# Extracted 31 bands from ARAD_HS_0370.mat and saved as TIFF in data/post\ARAD_HS_0370.
# Extracted 31 bands from ARAD_HS_0371.mat and saved as TIFF in data/post\ARAD_HS_0371.
# Extracted 31 bands from ARAD_HS_0372.mat and saved as TIFF in data/post\ARAD_HS_0372.
# Extracted 31 bands from ARAD_HS_0373.mat and saved as TIFF in data/post\ARAD_HS_0373.
# Extracted 31 bands from ARAD_HS_0374.mat and saved as TIFF in data/post\ARAD_HS_0374.
# Extracted 31 bands from ARAD_HS_0375.mat and saved as TIFF in data/post\ARAD_HS_0375.

# %% [markdown]
# import os
# import glob
# import matplotlib.pyplot as plt
# import cv2
#
# # Set the folder containing the TIFF images of the hyperspectral bands
# # output_folder = r'C:\Users\deepa\Downloads\HSI_Dataset'  # Change this to your output folder
#
# # Get all subfolders containing TIFF images
# subfolders = [f.path for f in os.scandir(output_folder) if f.is_dir()]
#
# # Loop through each subfolder and visualize the bands
# for subfolder in subfolders:
#     band_files = sorted(glob.glob(os.path.join(subfolder, '*.tiff')))
#
#     # Print the number of bands and their names for debugging
#     print(f'Number of bands found in {os.path.basename(subfolder)}: {len(band_files)}')
#     print('Band files:', band_files)
#
#     # Proceed only if bands are found
#     if band_files:
#         # Set up the plotting area
#         num_bands = len(band_files)
#         cols = 5  # Number of columns in the display grid
#         rows = (num_bands + cols - 1) // cols  # Calculate number of rows needed
#
#         plt.figure(figsize=(15, 3 * rows))
#
#         # Loop through each band and display it
#         for i, band_file in enumerate(band_files):
#             band_data = cv2.imread(band_file, cv2.IMREAD_UNCHANGED)  # Read the TIFF file
#             plt.subplot(rows, cols, i + 1)
#             plt.imshow(band_data, cmap='gray')
#             plt.title(f'{os.path.basename(subfolder)} Band {i + 1}')  # Set title with subfolder name and band number
#             plt.axis('off')  # Hide the axis
#
#         plt.tight_layout()  # Adjust layout to prevent overlap
#         plt.show()
#     else:
#         print(f"No band files found in {subfolder}.")
