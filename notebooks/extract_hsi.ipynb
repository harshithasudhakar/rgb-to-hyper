# %%
import scipy.io

# Load the .mat file
mat_file_path = "data/pre/ARAD_HS_0002.mat"
mat_data = scipy.io.loadmat(mat_file_path)

# Print all available keys in the .mat file
print(mat_data.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'cube', 'bands', 'norm_factor'])

# %%
import os
import numpy as np
import tifffile as tiff
from scipy.io import loadmat

# Folder containing the .mat files
input_folder = "data/pre"

# Folder to save the extracted TIFF files
output_folder = "data/post"
os.makedirs(output_folder, exist_ok=True)  # Create the output folder if it doesn't exist

# Get all .mat files in the input folder
mat_files = [f for f in os.listdir(input_folder) if f.endswith('.mat')]

# Loop through each .mat file
for mat_file in mat_files:
    mat_file_path = os.path.join(input_folder, mat_file)  # Full path of the .mat file
    
    # Load the .mat file
    mat_data = loadmat(mat_file_path)

    # Extract the 'cube' data
    if 'cube' in mat_data:
        cube_data = mat_data['cube']
        
        # Create a folder for the current .mat file's bands
        mat_file_name = os.path.splitext(mat_file)[0]
        mat_output_folder = os.path.join(output_folder, mat_file_name)
        os.makedirs(mat_output_folder, exist_ok=True)

        # Loop through each band and save as a TIFF file
        for i in range(cube_data.shape[2]):
            band_data = cube_data[:, :, i]
            tiff_file_path = os.path.join(mat_output_folder, f'{mat_file_name}_band_{i + 1}.tiff')
            tiff.imwrite(tiff_file_path, band_data.astype(np.float32))  # Save the TIFF file
        print(f"Extracted {cube_data.shape[2]} bands from {mat_file} and saved as TIFF in {mat_output_folder}.")
    else:
        print(f"'cube' key not found in {mat_file}.")
# Out:
# Extracted 31 bands from ARAD_HS_0037.mat and saved as TIFF in data/post/ARAD_HS_0037.
# Extracted 31 bands from ARAD_HS_0026.mat and saved as TIFF in data/post/ARAD_HS_0026.
# Extracted 31 bands from ARAD_HS_0002.mat and saved as TIFF in data/post/ARAD_HS_0002.
# Extracted 31 bands from ARAD_HS_0053.mat and saved as TIFF in data/post/ARAD_HS_0053.
# Extracted 31 bands from ARAD_HS_0010.mat and saved as TIFF in data/post/ARAD_HS_0010.
# Extracted 31 bands from ARAD_HS_0006.mat and saved as TIFF in data/post/ARAD_HS_0006.
# Extracted 31 bands from ARAD_HS_0003.mat and saved as TIFF in data/post/ARAD_HS_0003.
# Extracted 31 bands from ARAD_HS_0063.mat and saved as TIFF in data/post/ARAD_HS_0063.
# Extracted 31 bands from ARAD_HS_0044.mat and saved as TIFF in data/post/ARAD_HS_0044.
# Extracted 31 bands from ARAD_HS_0018.mat and saved as TIFF in data/post/ARAD_HS_0018.
# Extracted 31 bands from ARAD_HS_0038.mat and saved as TIFF in data/post/ARAD_HS_0038.
# Extracted 31 bands from ARAD_HS_0059.mat and saved as TIFF in data/post/ARAD_HS_0059.
# Extracted 31 bands from ARAD_HS_0074.mat and saved as TIFF in data/post/ARAD_HS_0074.
# Extracted 31 bands from ARAD_HS_0045.mat and saved as TIFF in data/post/ARAD_HS_0045.
# Extracted 31 bands from ARAD_HS_0031.mat and saved as TIFF in data/post/ARAD_HS_0031.
# Extracted 31 bands from ARAD_HS_0057.mat and saved as TIFF in data/post/ARAD_HS_0057.
# Extracted 31 bands from ARAD_HS_0036.mat and saved as TIFF in data/post/ARAD_HS_0036.
# Extracted 31 bands from ARAD_HS_0029.mat and saved as TIFF in data/post/ARAD_HS_0029.
# Extracted 31 bands from ARAD_HS_0004.mat and saved as TIFF in data/post/ARAD_HS_0004.
# Extracted 31 bands from ARAD_HS_0067.mat and saved as TIFF in data/post/ARAD_HS_0067.
# Extracted 31 bands from ARAD_HS_0048.mat and saved as TIFF in data/post/ARAD_HS_0048.
# Extracted 31 bands from ARAD_HS_0022.mat and saved as TIFF in data/post/ARAD_HS_0022.
# Extracted 31 bands from ARAD_HS_0066.mat and saved as TIFF in data/post/ARAD_HS_0066.
# Extracted 31 bands from ARAD_HS_0007.mat and saved as TIFF in data/post/ARAD_HS_0007.
# Extracted 31 bands from ARAD_HS_0049.mat and saved as TIFF in data/post/ARAD_HS_0049.
# Extracted 31 bands from ARAD_HS_0028.mat and saved as TIFF in data/post/ARAD_HS_0028.
# Extracted 31 bands from ARAD_HS_0064.mat and saved as TIFF in data/post/ARAD_HS_0064.
# Extracted 31 bands from ARAD_HS_0050.mat and saved as TIFF in data/post/ARAD_HS_0050.
# Extracted 31 bands from ARAD_HS_0061.mat and saved as TIFF in data/post/ARAD_HS_0061.
# Extracted 31 bands from ARAD_HS_0032.mat and saved as TIFF in data/post/ARAD_HS_0032.
# Extracted 31 bands from ARAD_HS_0008.mat and saved as TIFF in data/post/ARAD_HS_0008.
# Extracted 31 bands from ARAD_HS_0051.mat and saved as TIFF in data/post/ARAD_HS_0051.
# Extracted 31 bands from ARAD_HS_0011.mat and saved as TIFF in data/post/ARAD_HS_0011.
# Extracted 31 bands from ARAD_HS_0023.mat and saved as TIFF in data/post/ARAD_HS_0023.
# Extracted 31 bands from ARAD_HS_0068.mat and saved as TIFF in data/post/ARAD_HS_0068.
# Extracted 31 bands from ARAD_HS_0021.mat and saved as TIFF in data/post/ARAD_HS_0021.
# Extracted 31 bands from ARAD_HS_0065.mat and saved as TIFF in data/post/ARAD_HS_0065.
# Extracted 31 bands from ARAD_HS_0009.mat and saved as TIFF in data/post/ARAD_HS_0009.
# Extracted 31 bands from ARAD_HS_0041.mat and saved as TIFF in data/post/ARAD_HS_0041.
# Extracted 31 bands from ARAD_HS_0024.mat and saved as TIFF in data/post/ARAD_HS_0024.
# Extracted 31 bands from ARAD_HS_0062.mat and saved as TIFF in data/post/ARAD_HS_0062.
# Extracted 31 bands from ARAD_HS_0054.mat and saved as TIFF in data/post/ARAD_HS_0054.
# Extracted 31 bands from ARAD_HS_0052.mat and saved as TIFF in data/post/ARAD_HS_0052.
# Extracted 31 bands from ARAD_HS_0012.mat and saved as TIFF in data/post/ARAD_HS_0012.
# Extracted 31 bands from ARAD_HS_0070.mat and saved as TIFF in data/post/ARAD_HS_0070.
# Extracted 31 bands from ARAD_HS_0069.mat and saved as TIFF in data/post/ARAD_HS_0069.
# Extracted 31 bands from ARAD_HS_0055.mat and saved as TIFF in data/post/ARAD_HS_0055.
# Extracted 31 bands from ARAD_HS_0040.mat and saved as TIFF in data/post/ARAD_HS_0040.
# Extracted 31 bands from ARAD_HS_0027.mat and saved as TIFF in data/post/ARAD_HS_0027.
# Extracted 31 bands from ARAD_HS_0015.mat and saved as TIFF in data/post/ARAD_HS_0015.
# Extracted 31 bands from ARAD_HS_0025.mat and saved as TIFF in data/post/ARAD_HS_0025.
# Extracted 31 bands from ARAD_HS_0034.mat and saved as TIFF in data/post/ARAD_HS_0034.
# Extracted 31 bands from ARAD_HS_0072.mat and saved as TIFF in data/post/ARAD_HS_0072.
# Extracted 31 bands from ARAD_HS_0013.mat and saved as TIFF in data/post/ARAD_HS_0013.
# Extracted 31 bands from ARAD_HS_0017.mat and saved as TIFF in data/post/ARAD_HS_0017.
# Extracted 31 bands from ARAD_HS_0014.mat and saved as TIFF in data/post/ARAD_HS_0014.
# Extracted 31 bands from ARAD_HS_0058.mat and saved as TIFF in data/post/ARAD_HS_0058.
# Extracted 31 bands from ARAD_HS_0019.mat and saved as TIFF in data/post/ARAD_HS_0019.
# Extracted 31 bands from ARAD_HS_0001.mat and saved as TIFF in data/post/ARAD_HS_0001.
# Extracted 31 bands from ARAD_HS_0046.mat and saved as TIFF in data/post/ARAD_HS_0046.
# Extracted 31 bands from ARAD_HS_0042.mat and saved as TIFF in data/post/ARAD_HS_0042.
# Extracted 31 bands from ARAD_HS_0020.mat and saved as TIFF in data/post/ARAD_HS_0020.
# Extracted 31 bands from ARAD_HS_0035.mat and saved as TIFF in data/post/ARAD_HS_0035.
# Extracted 31 bands from ARAD_HS_0056.mat and saved as TIFF in data/post/ARAD_HS_0056.
# Extracted 31 bands from ARAD_HS_0033.mat and saved as TIFF in data/post/ARAD_HS_0033.
# Extracted 31 bands from ARAD_HS_0047.mat and saved as TIFF in data/post/ARAD_HS_0047.
# Extracted 31 bands from ARAD_HS_0005.mat and saved as TIFF in data/post/ARAD_HS_0005.
# Extracted 31 bands from ARAD_HS_0060.mat and saved as TIFF in data/post/ARAD_HS_0060.
# Extracted 31 bands from ARAD_HS_0071.mat and saved as TIFF in data/post/ARAD_HS_0071.
# Extracted 31 bands from ARAD_HS_0016.mat and saved as TIFF in data/post/ARAD_HS_0016.
# Extracted 31 bands from ARAD_HS_0075.mat and saved as TIFF in data/post/ARAD_HS_0075.
# Extracted 31 bands from ARAD_HS_0039.mat and saved as TIFF in data/post/ARAD_HS_0039.
# Extracted 31 bands from ARAD_HS_0043.mat and saved as TIFF in data/post/ARAD_HS_0043.
# Extracted 31 bands from ARAD_HS_0030.mat and saved as TIFF in data/post/ARAD_HS_0030.
# Extracted 31 bands from ARAD_HS_0073.mat and saved as TIFF in data/post/ARAD_HS_0073.

# %%
# import os
# import glob
# import matplotlib.pyplot as plt
# import cv2

# # Set the folder containing the TIFF images of the hyperspectral bands
# # output_folder = r'C:\Users\deepa\Downloads\HSI_Dataset'  # Change this to your output folder

# # Get all subfolders containing TIFF images
# subfolders = [f.path for f in os.scandir(output_folder) if f.is_dir()]

# # Loop through each subfolder and visualize the bands
# for subfolder in subfolders:
#     band_files = sorted(glob.glob(os.path.join(subfolder, '*.tiff')))

#     # Print the number of bands and their names for debugging
#     print(f'Number of bands found in {os.path.basename(subfolder)}: {len(band_files)}')
#     print('Band files:', band_files)

#     # Proceed only if bands are found
#     if band_files:
#         # Set up the plotting area
#         num_bands = len(band_files)
#         cols = 5  # Number of columns in the display grid
#         rows = (num_bands + cols - 1) // cols  # Calculate number of rows needed

#         plt.figure(figsize=(15, 3 * rows))

#         # Loop through each band and display it
#         for i, band_file in enumerate(band_files):
#             band_data = cv2.imread(band_file, cv2.IMREAD_UNCHANGED)  # Read the TIFF file
#             plt.subplot(rows, cols, i + 1)
#             plt.imshow(band_data, cmap='gray')
#             plt.title(f'{os.path.basename(subfolder)} Band {i + 1}')  # Set title with subfolder name and band number
#             plt.axis('off')  # Hide the axis

#         plt.tight_layout()  # Adjust layout to prevent overlap
#         plt.show()
#     else:
#         print(f"No band files found in {subfolder}.")
